# %%
import pandas as pd

# %% [markdown]
# 1. csv 불러오기

# %% [markdown]
# 2. 합치기

# %%
df_list =[]

# %%
for url in ['csv2.csv', 'csv3.csv', 'csv4.csv']:
    csv = pd.read_csv(url)
    df_list.append(csv)

# %%
df = pd.concat(df_list)

# %%
df
# Out:
#     이수\n구분     과목코드         교과목명  교수명  \
# 0       교필  AC00013          말과글  오현화
# 1       교필  AC00013          말과글  오현화
# 2       교필  AC00013          말과글  곽승숙
# 3       교필  AC00013          말과글  곽승숙
# 4       교필  AC00013          말과글  오현화
# ..     ...      ...          ...  ...
# 193     전선  XE00006     딥러닝프레임워크  미지정
# 194     전선  XE00007      확률과랜덤변수  이상윤
# 195     전선  XE00013  Python프로그래밍  홍성준
# 196     전선  XE00014   인공지능캡스톤디자인  이상윤
# 197     전선  XE00015        컴퓨터비전  미지정
#
#                                                 강의실/시간
# 0                               1504 / 수 / 09:00~10:50
# 1                               1504 / 수 / 11:00~12:50
# 2                               1505 / 수 / 09:00~10:50
# 3                               1505 / 수 / 11:00~12:50
# 4                               1504 / 목 / 09:00~10:50
# ..                                                 ...
# 193                           6405 / 목요일 / 09:00~11:50
# 194  6405 / 화요일 / 13:30~14:45\n6405 / 목요일 / 13:30~1...
# 195  B105 / 월요일 / 15:00~16:15\nB105 / 수요일 / 15:00~1...
# 196                           6405 / 금요일 / 12:00~14:50
# 197  6405 / 화요일 / 15:00~16:15\n6405 / 목요일 / 15:00~1...
#
# [302 rows x 5 columns]

# %%
df.reset_index(drop=True, inplace=True)
df
# Out:
#     이수\n구분     과목코드         교과목명  교수명  \
# 0       교필  AC00013          말과글  오현화
# 1       교필  AC00013          말과글  오현화
# 2       교필  AC00013          말과글  곽승숙
# 3       교필  AC00013          말과글  곽승숙
# 4       교필  AC00013          말과글  오현화
# ..     ...      ...          ...  ...
# 297     전선  XE00006     딥러닝프레임워크  미지정
# 298     전선  XE00007      확률과랜덤변수  이상윤
# 299     전선  XE00013  Python프로그래밍  홍성준
# 300     전선  XE00014   인공지능캡스톤디자인  이상윤
# 301     전선  XE00015        컴퓨터비전  미지정
#
#                                                 강의실/시간
# 0                               1504 / 수 / 09:00~10:50
# 1                               1504 / 수 / 11:00~12:50
# 2                               1505 / 수 / 09:00~10:50
# 3                               1505 / 수 / 11:00~12:50
# 4                               1504 / 목 / 09:00~10:50
# ..                                                 ...
# 297                           6405 / 목요일 / 09:00~11:50
# 298  6405 / 화요일 / 13:30~14:45\n6405 / 목요일 / 13:30~1...
# 299  B105 / 월요일 / 15:00~16:15\nB105 / 수요일 / 15:00~1...
# 300                           6405 / 금요일 / 12:00~14:50
# 301  6405 / 화요일 / 15:00~16:15\n6405 / 목요일 / 15:00~1...
#
# [302 rows x 5 columns]

# %% [markdown]
# 3. 열 변수 이름 변경
# chapel.columns = ['kind','code','class_name','prof','room_time']

# %%
df.columns = ['kind','code','classname','prof','roomNtime']
df
# Out:
#     kind     code    classname prof  \
# 0     교필  AC00013          말과글  오현화
# 1     교필  AC00013          말과글  오현화
# 2     교필  AC00013          말과글  곽승숙
# 3     교필  AC00013          말과글  곽승숙
# 4     교필  AC00013          말과글  오현화
# ..   ...      ...          ...  ...
# 297   전선  XE00006     딥러닝프레임워크  미지정
# 298   전선  XE00007      확률과랜덤변수  이상윤
# 299   전선  XE00013  Python프로그래밍  홍성준
# 300   전선  XE00014   인공지능캡스톤디자인  이상윤
# 301   전선  XE00015        컴퓨터비전  미지정
#
#                                              roomNtime
# 0                               1504 / 수 / 09:00~10:50
# 1                               1504 / 수 / 11:00~12:50
# 2                               1505 / 수 / 09:00~10:50
# 3                               1505 / 수 / 11:00~12:50
# 4                               1504 / 목 / 09:00~10:50
# ..                                                 ...
# 297                           6405 / 목요일 / 09:00~11:50
# 298  6405 / 화요일 / 13:30~14:45\n6405 / 목요일 / 13:30~1...
# 299  B105 / 월요일 / 15:00~16:15\nB105 / 수요일 / 15:00~1...
# 300                           6405 / 금요일 / 12:00~14:50
# 301  6405 / 화요일 / 15:00~16:15\n6405 / 목요일 / 15:00~1...
#
# [302 rows x 5 columns]

# %% [markdown]
# 4. 일주일 두번 수업 나누기

# %% [markdown]
# 5. 강의실, 요일, 시간 나누기

# %% [markdown]
# 6. 예외 처리

# %% [markdown]
# 7. 관 변수 추가

# %% [markdown]
# 8. 함수 작동 편하게 정렬
